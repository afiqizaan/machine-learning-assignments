# %% [markdown]
# # Pima Indians Diabetes

# %% [markdown]
# # Breakdown of this notebook:
# 1. **Importing Libraries**
# 2. **Loading the dataset:** Load the data and import the libraries
# 3. **Data Cleaning:** <br>
#  - Deleting redundant columns.
#  - Renaming the columns.
#  - Dropping duplicates.
#  - Cleaning individual columns.
#  - Remove the NaN values from the dataset
#  - Some Transformations
# 3. **Traininig the Model**
# 4. **Generate a Classification Report**

# %% [markdown]
# <h3>Importing Libraries</h3>

# %%
import sys
import pandas as pd
import numpy as np
import sklearn
import matplotlib
import keras

print('Python: {}'.format(sys.version))
print('Pandas: {}'.format(pd.__version__))
print('Numpy: {}'.format(np.__version__))
print('Sklearn: {}'.format(sklearn.__version__))
print('Matplotlib: {}'.format(matplotlib.__version__))


import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix
# Out:
# Python: 3.7.13 (default, Apr 24 2022, 01:04:09)
# [GCC 7.5.0]
# Pandas: 1.3.5
# Numpy: 1.21.6
# Sklearn: 1.0.2
# Matplotlib: 3.2.2

# %% [markdown]
# **Loading the Dataset**

# %%
df=pd.read_csv("diabetes.csv")

# %%
#Describe the dataset
df.describe()
# Out:
#        Pregnancies      Glucose  BloodPressure  SkinThickness      Insulin  \
# count  2000.000000  2000.000000    2000.000000    2000.000000  2000.000000
# mean      3.703500   121.182500      69.145500      20.935000    80.254000
# std       3.306063    32.068636      19.188315      16.103243   111.180534
# min       0.000000     0.000000       0.000000       0.000000     0.000000
# 25%       1.000000    99.000000      63.500000       0.000000     0.000000
# 50%       3.000000   117.000000      72.000000      23.000000    40.000000
# 75%       6.000000   141.000000      80.000000      32.000000   130.000000
# max      17.000000   199.000000     122.000000     110.000000   744.000000
#
#                BMI  DiabetesPedigreeFunction          Age      Outcome
# count  2000.000000               2000.000000  2000.000000  2000.000000
# mean     32.193000                  0.470930    33.090500     0.342000
# std       8.149901                  0.323553    11.786423     0.474498
# min       0.000000                  0.078000    21.000000     0.000000
# 25%      27.375000                  0.244000    24.000000     0.000000
# 50%      32.300000                  0.376000    29.000000     0.000000
# 75%      36.800000                  0.624000    40.000000     1.000000
# max      80.600000                  2.420000    81.000000     1.000000

# %% [markdown]
# **DataFrame where the Glucose concentration of a patient is pulled to 0**

# %%
df[df['Glucose'] == 0]
# Out:
#       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 20              6        0             68             41        0  39.0
# 75              1        0             48             20        0  24.7
# 182             1        0             74             20       23  27.7
# 342             1        0             68             35        0  32.0
# 349             5        0             80             32        0  41.0
# 502             6        0             68             41        0  39.0
# 812             1        0             68             35        0  32.0
# 819             5        0             80             32        0  41.0
# 972             6        0             68             41        0  39.0
# 1340            1        0             74             20       23  27.7
# 1595            1        0             68             35        0  32.0
# 1602            5        0             80             32        0  41.0
# 1896            1        0             48             20        0  24.7
#
#       DiabetesPedigreeFunction  Age  Outcome
# 20                       0.727   41        1
# 75                       0.140   22        0
# 182                      0.299   21        0
# 342                      0.389   22        0
# 349                      0.346   37        1
# 502                      0.727   41        1
# 812                      0.389   22        0
# 819                      0.346   37        1
# 972                      0.727   41        1
# 1340                     0.299   21        0
# 1595                     0.389   22        0
# 1602                     0.346   37        1
# 1896                     0.140   22        0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               2000 non-null   int64
#  1   Glucose                   2000 non-null   int64
#  2   BloodPressure             2000 non-null   int64
#  3   SkinThickness             2000 non-null   int64
#  4   Insulin                   2000 non-null   int64
#  5   BMI                       2000 non-null   float64
#  6   DiabetesPedigreeFunction  2000 non-null   float64
#  7   Age                       2000 non-null   int64
#  8   Outcome                   2000 non-null   int64
# dtypes: float64(2), int64(7)
# memory usage: 140.8 KB

# %% [markdown]
# **Removing the Duplicates**

# %%
df.duplicated().sum()
df.drop_duplicates(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 744 entries, 0 to 1568
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               744 non-null    int64
#  1   Glucose                   744 non-null    int64
#  2   BloodPressure             744 non-null    int64
#  3   SkinThickness             744 non-null    int64
#  4   Insulin                   744 non-null    int64
#  5   BMI                       744 non-null    float64
#  6   DiabetesPedigreeFunction  744 non-null    float64
#  7   Age                       744 non-null    int64
#  8   Outcome                   744 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 58.1 KB

# %% [markdown]
# **Preprocess the data, mark zero values as NaN and drop**

# %%
columns = ['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI']

for col in columns:
    df[col].replace(0, np.NaN, inplace=True)
    
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   744.000000  739.000000     710.000000     529.000000  385.000000
# mean      3.752688  121.710419      72.261972      29.406427  153.698701
# std       3.335541   30.456331      12.332675      11.137877  112.839569
# min       0.000000   44.000000      24.000000       7.000000   14.000000
# 25%       1.000000   99.500000      64.000000      22.000000   76.000000
# 50%       3.000000  117.000000      72.000000      29.000000  126.000000
# 75%       6.000000  141.000000      80.000000      36.000000  190.000000
# max      17.000000  199.000000     122.000000     110.000000  744.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  734.000000                744.000000  744.000000  744.000000
# mean    32.668801                  0.472355   33.142473    0.340054
# std      7.341531                  0.326181   11.751286    0.474046
# min     18.200000                  0.078000   21.000000    0.000000
# 25%     27.500000                  0.244000   24.000000    0.000000
# 50%     32.400000                  0.375500   29.000000    0.000000
# 75%     36.800000                  0.632500   40.250000    1.000000
# max     80.600000                  2.420000   81.000000    1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 744 entries, 0 to 1568
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               744 non-null    int64
#  1   Glucose                   739 non-null    float64
#  2   BloodPressure             710 non-null    float64
#  3   SkinThickness             529 non-null    float64
#  4   Insulin                   385 non-null    float64
#  5   BMI                       734 non-null    float64
#  6   DiabetesPedigreeFunction  744 non-null    float64
#  7   Age                       744 non-null    int64
#  8   Outcome                   744 non-null    int64
# dtypes: float64(6), int64(3)
# memory usage: 58.1 KB

# %% [markdown]
# **Drop rows with missing values**

# %%
df.dropna(inplace=True)

# summarize the number of rows and columns in df
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   381.000000  381.000000     381.000000     381.000000  381.000000
# mean      3.254593  122.624672      70.708661      29.270341  153.889764
# std       3.169055   30.647801      12.437704      10.630536  113.097366
# min       0.000000   56.000000      24.000000       7.000000   14.000000
# 25%       1.000000   99.000000      62.000000      21.000000   76.000000
# 50%       2.000000  119.000000      70.000000      29.000000  126.000000
# 75%       5.000000  143.000000      78.000000      37.000000  190.000000
# max      17.000000  198.000000     110.000000      63.000000  744.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  381.000000                381.000000  381.000000  381.000000
# mean    33.177690                  0.524530   30.787402    0.320210
# std      7.105995                  0.335632   10.140822    0.467171
# min     18.200000                  0.085000   21.000000    0.000000
# 25%     28.400000                  0.282000   23.000000    0.000000
# 50%     33.300000                  0.452000   27.000000    0.000000
# 75%     37.200000                  0.687000   36.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 381 entries, 1 to 1567
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               381 non-null    int64
#  1   Glucose                   381 non-null    float64
#  2   BloodPressure             381 non-null    float64
#  3   SkinThickness             381 non-null    float64
#  4   Insulin                   381 non-null    float64
#  5   BMI                       381 non-null    float64
#  6   DiabetesPedigreeFunction  381 non-null    float64
#  7   Age                       381 non-null    int64
#  8   Outcome                   381 non-null    int64
# dtypes: float64(6), int64(3)
# memory usage: 29.8 KB

# %% [markdown]
# ## Training the Model

# %% [markdown]
# **Convert dataframe to numpy array**

# %%
dataset = df.values
print(dataset.shape)
# Out:
# (381, 9)

# %% [markdown]
# **Split into input (X) and an output (Y)**

# %%
X = dataset[:,0:8]
Y = dataset[:, 8].astype(int)

# %%
print(X.shape)
print(Y.shape)
print(Y[:5])
# Out:
# (381, 8)
# (381,)
# [0 1 0 0 0]

# %% [markdown]
# **Normalize the data using sklearn StandardScaler**

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler().fit(X)

# %%
print(scaler)
# Out:
# StandardScaler()

# %% [markdown]
# **Transform and display the training data**

# %%
X_standardized = scaler.transform(X)

data = pd.DataFrame(X_standardized)
data.describe()
# Out:
#                   0             1             2             3             4  \
# count  3.810000e+02  3.810000e+02  3.810000e+02  3.810000e+02  3.810000e+02
# mean  -5.973641e-18  1.631824e-17  3.904721e-16  1.298174e-16  1.959646e-17
# std    1.001315e+00  1.001315e+00  1.001315e+00  1.001315e+00  1.001315e+00
# min   -1.028342e+00 -2.176739e+00 -3.760347e+00 -2.097695e+00 -1.238523e+00
# 25%   -7.123758e-01 -7.718576e-01 -7.011031e-01 -7.790027e-01 -6.896021e-01
# 50%   -3.964094e-01 -1.184241e-01 -5.705179e-02 -2.546407e-02 -2.469238e-01
# 75%    5.514900e-01  6.656961e-01  5.869995e-01  7.280745e-01  3.197043e-01
# max    4.343087e+00  2.462638e+00  3.163205e+00  3.177075e+00  5.224580e+00
#
#                   5             6             7
# count  3.810000e+02  3.810000e+02  3.810000e+02
# mean  -1.270491e-16  9.149870e-17  1.357911e-16
# std    1.001315e+00  1.001315e+00  1.001315e+00
# min   -2.110526e+00 -1.311281e+00 -9.664179e-01
# 25%   -6.732305e-01 -7.235571e-01 -7.689359e-01
# 50%    1.723482e-02 -2.163843e-01 -3.739718e-01
# 75%    5.667889e-01  4.847075e-01  5.146972e-01
# max    4.780037e+00  5.654887e+00  4.958042e+00

# %% [markdown]
# **Import necessary sklearn and keras packages**

# %%
from sklearn.model_selection import GridSearchCV, KFold
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasClassifier
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# **Do a grid search for the optimal batch size and number of epochs**

# %%
# Define a random seed
seed = 6
np.random.seed(seed)

# Start defining the model
def create_model():
    # create model
    model = Sequential()
    model.add(Dense(8, input_dim = 8, kernel_initializer='normal', activation='relu'))
    model.add(Dense(4, input_dim = 8, kernel_initializer='normal', activation='relu'))
    model.add(Dense(1, activation='sigmoid'))
    
    # compile the model
    adam = Adam(lr = 0.01)
    model.compile(loss = 'binary_crossentropy', optimizer = adam, metrics = ['accuracy'])
    return model

# create the model
model = KerasClassifier(build_fn = create_model, verbose = 1)

# define the grid search parameters
batch_size = [10, 20, 40]
epochs = [10, 50, 100]

# make a dictionary of the grid search parameters
param_grid = dict(batch_size=batch_size, epochs=epochs)

# build and fit the GridSearchCV
grid = GridSearchCV(estimator = model, param_grid = param_grid, cv = KFold(random_state=None), verbose = 10)
grid_results = grid.fit(X_standardized, Y)

# summarize the results
print("Best: {0}, using {1}".format(grid_results.best_score_, grid_results.best_params_))
means = grid_results.cv_results_['mean_test_score']
stds = grid_results.cv_results_['std_test_score']
params = grid_results.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print('{0} ({1}) with: {2}'.format(mean, stdev, param))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5; 1/9] START batch_size=10, epochs=10....................................
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Epoch 1/10
# 31/31 [==============================] - 1s 1ms/step - loss: 0.5854 - accuracy: 0.6678
# Epoch 2/10
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4755 - accuracy: 0.6711
# Epoch 3/10
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4622 - accuracy: 0.7763
# Epoch 4/10
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4545 - accuracy: 0.7895
# Epoch 5/10
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4360 - accuracy: 0.8191
# Epoch 6/10
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4225 - accuracy: 0.8092
# Epoch 7/10
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4142 - accuracy: 0.8191
# Epoch 8/10
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4053 - accuracy: 0.8289
# Epoch 9/10
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3984 - accuracy: 0.8355
# Epoch 10/10
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3885 - accuracy: 0.8388
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4948 - accuracy: 0.7532
# [CV 1/5; 1/9] END .....batch_size=10, epochs=10;, score=0.753 total time=   2.5s
# [CV 2/5; 1/9] START batch_size=10, epochs=10....................................
# Epoch 1/10
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# 31/31 [==============================] - 1s 2ms/step - loss: 0.5727 - accuracy: 0.7344
# Epoch 2/10
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4110 - accuracy: 0.8164
# Epoch 3/10
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3836 - accuracy: 0.8230
# Epoch 4/10
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3711 - accuracy: 0.8295
# Epoch 5/10
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3661 - accuracy: 0.8361
# Epoch 6/10
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3593 - accuracy: 0.8361
# Epoch 7/10
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3481 - accuracy: 0.8459
# Epoch 8/10
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3490 - accuracy: 0.8393
# Epoch 9/10
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3414 - accuracy: 0.8426
# Epoch 10/10
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3355 - accuracy: 0.8492
# 8/8 [==============================] - 0s 2ms/step - loss: 0.8096 - accuracy: 0.6579
# [CV 2/5; 1/9] END .....batch_size=10, epochs=10;, score=0.658 total time=   1.4s
# [CV 3/5; 1/9] START batch_size=10, epochs=10....................................
# Epoch 1/10
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# 31/31 [==============================] - 1s 1ms/step - loss: 0.6441 - accuracy: 0.6623
# Epoch 2/10
# 31/31 [==============================] - 0s 2ms/step - loss: 0.5006 - accuracy: 0.6787
# Epoch 3/10
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4715 - accuracy: 0.6787
# Epoch 4/10
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4640 - accuracy: 0.6918
# Epoch 5/10
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4557 - accuracy: 0.7934
# Epoch 6/10
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4395 - accuracy: 0.7902
# Epoch 7/10
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4319 - accuracy: 0.8131
# Epoch 8/10
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4276 - accuracy: 0.7902
# Epoch 9/10
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4134 - accuracy: 0.8066
# Epoch 10/10
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4119 - accuracy: 0.8066
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4423 - accuracy: 0.7763
# [CV 3/5; 1/9] END .....batch_size=10, epochs=10;, score=0.776 total time=   1.4s
# [CV 4/5; 1/9] START batch_size=10, epochs=10....................................
# Epoch 1/10
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# 31/31 [==============================] - 1s 2ms/step - loss: 0.6035 - accuracy: 0.6525
# Epoch 2/10
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4856 - accuracy: 0.7377
# Epoch 3/10
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4608 - accuracy: 0.7541
# Epoch 4/10
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4457 - accuracy: 0.7738
# Epoch 5/10
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4344 - accuracy: 0.7902
# Epoch 6/10
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4326 - accuracy: 0.7705
# Epoch 7/10
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4220 - accuracy: 0.8033
# Epoch 8/10
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4256 - accuracy: 0.7738
# Epoch 9/10
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4132 - accuracy: 0.8000
# Epoch 10/10
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4049 - accuracy: 0.7967
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3767 - accuracy: 0.8289
# [CV 4/5; 1/9] END .....batch_size=10, epochs=10;, score=0.829 total time=   1.5s
# [CV 5/5; 1/9] START batch_size=10, epochs=10....................................
# Epoch 1/10
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# 31/31 [==============================] - 1s 1ms/step - loss: 0.6649 - accuracy: 0.7344
# Epoch 2/10
# 31/31 [==============================] - 0s 2ms/step - loss: 0.6010 - accuracy: 0.7738
# Epoch 3/10
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5541 - accuracy: 0.8000
# Epoch 4/10
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5243 - accuracy: 0.7967
# Epoch 5/10
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5026 - accuracy: 0.7902
# Epoch 6/10
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4851 - accuracy: 0.8066
# Epoch 7/10
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4759 - accuracy: 0.8066
# Epoch 8/10
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4662 - accuracy: 0.8066
# Epoch 9/10
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4530 - accuracy: 0.8066
# Epoch 10/10
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4437 - accuracy: 0.8164
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5040 - accuracy: 0.8158
# [CV 5/5; 1/9] END .....batch_size=10, epochs=10;, score=0.816 total time=   1.3s
# [CV 1/5; 2/9] START batch_size=10, epochs=50....................................
# Epoch 1/50
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# 31/31 [==============================] - 1s 1ms/step - loss: 0.5826 - accuracy: 0.6678
# Epoch 2/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4820 - accuracy: 0.6711
# Epoch 3/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4579 - accuracy: 0.7434
# Epoch 4/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4490 - accuracy: 0.7961
# Epoch 5/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4418 - accuracy: 0.7928
# Epoch 6/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4289 - accuracy: 0.8026
# Epoch 7/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4177 - accuracy: 0.8158
# Epoch 8/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4130 - accuracy: 0.8289
# Epoch 9/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4012 - accuracy: 0.8224
# Epoch 10/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3897 - accuracy: 0.8322
# Epoch 11/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3866 - accuracy: 0.8289
# Epoch 12/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3757 - accuracy: 0.8421
# Epoch 13/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3674 - accuracy: 0.8454
# Epoch 14/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3584 - accuracy: 0.8487
# Epoch 15/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3529 - accuracy: 0.8355
# Epoch 16/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3595 - accuracy: 0.8487
# Epoch 17/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3473 - accuracy: 0.8553
# Epoch 18/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3445 - accuracy: 0.8520
# Epoch 19/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3364 - accuracy: 0.8586
# Epoch 20/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3316 - accuracy: 0.8684
# Epoch 21/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3280 - accuracy: 0.8586
# Epoch 22/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3221 - accuracy: 0.8750
# Epoch 23/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3201 - accuracy: 0.8684
# Epoch 24/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3234 - accuracy: 0.8717
# Epoch 25/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3128 - accuracy: 0.8750
# Epoch 26/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3165 - accuracy: 0.8684
# Epoch 27/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3118 - accuracy: 0.8651
# Epoch 28/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3067 - accuracy: 0.8783
# Epoch 29/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3005 - accuracy: 0.8816
# Epoch 30/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3016 - accuracy: 0.8750
# Epoch 31/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.2984 - accuracy: 0.8783
# Epoch 32/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.2955 - accuracy: 0.8783
# Epoch 33/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3030 - accuracy: 0.8783
# Epoch 34/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.2978 - accuracy: 0.8783
# Epoch 35/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.2878 - accuracy: 0.8849
# Epoch 36/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3098 - accuracy: 0.8717
# Epoch 37/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2850 - accuracy: 0.8882
# Epoch 38/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3174 - accuracy: 0.8684
# Epoch 39/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3127 - accuracy: 0.8750
# Epoch 40/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2897 - accuracy: 0.8684
# Epoch 41/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.2835 - accuracy: 0.8849
# Epoch 42/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2808 - accuracy: 0.8882
# Epoch 43/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2888 - accuracy: 0.8849
# Epoch 44/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.2841 - accuracy: 0.8914
# Epoch 45/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2795 - accuracy: 0.8849
# Epoch 46/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.2757 - accuracy: 0.8914
# Epoch 47/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.2718 - accuracy: 0.8882
# Epoch 48/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.2760 - accuracy: 0.8914
# Epoch 49/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.2762 - accuracy: 0.8882
# Epoch 50/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.2722 - accuracy: 0.8914
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7872 - accuracy: 0.7403
# [CV 1/5; 2/9] END .....batch_size=10, epochs=50;, score=0.740 total time=   3.6s
# [CV 2/5; 2/9] START batch_size=10, epochs=50....................................
# Epoch 1/50
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# 31/31 [==============================] - 1s 1ms/step - loss: 0.5954 - accuracy: 0.7049
# Epoch 2/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4539 - accuracy: 0.7049
# Epoch 3/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4282 - accuracy: 0.7049
# Epoch 4/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4076 - accuracy: 0.8098
# Epoch 5/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3948 - accuracy: 0.8361
# Epoch 6/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3885 - accuracy: 0.8262
# Epoch 7/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3811 - accuracy: 0.8361
# Epoch 8/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3781 - accuracy: 0.8328
# Epoch 9/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3673 - accuracy: 0.8328
# Epoch 10/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3716 - accuracy: 0.8361
# Epoch 11/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3669 - accuracy: 0.8328
# Epoch 12/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3598 - accuracy: 0.8361
# Epoch 13/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3525 - accuracy: 0.8459
# Epoch 14/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3526 - accuracy: 0.8426
# Epoch 15/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3490 - accuracy: 0.8393
# Epoch 16/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3409 - accuracy: 0.8492
# Epoch 17/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3394 - accuracy: 0.8525
# Epoch 18/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3366 - accuracy: 0.8590
# Epoch 19/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3354 - accuracy: 0.8525
# Epoch 20/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3423 - accuracy: 0.8426
# Epoch 21/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3290 - accuracy: 0.8525
# Epoch 22/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3206 - accuracy: 0.8492
# Epoch 23/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3255 - accuracy: 0.8623
# Epoch 24/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3230 - accuracy: 0.8525
# Epoch 25/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3189 - accuracy: 0.8656
# Epoch 26/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3109 - accuracy: 0.8689
# Epoch 27/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3090 - accuracy: 0.8656
# Epoch 28/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3105 - accuracy: 0.8721
# Epoch 29/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3022 - accuracy: 0.8754
# Epoch 30/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3076 - accuracy: 0.8754
# Epoch 31/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2955 - accuracy: 0.8885
# Epoch 32/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.2954 - accuracy: 0.8852
# Epoch 33/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2946 - accuracy: 0.8885
# Epoch 34/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.2988 - accuracy: 0.8787
# Epoch 35/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2951 - accuracy: 0.8820
# Epoch 36/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2944 - accuracy: 0.8754
# Epoch 37/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.2868 - accuracy: 0.8885
# Epoch 38/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.2880 - accuracy: 0.8984
# Epoch 39/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.2955 - accuracy: 0.8820
# Epoch 40/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.2939 - accuracy: 0.8820
# Epoch 41/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.2826 - accuracy: 0.8885
# Epoch 42/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.2814 - accuracy: 0.8852
# Epoch 43/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2795 - accuracy: 0.8918
# Epoch 44/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.2880 - accuracy: 0.8918
# Epoch 45/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.2731 - accuracy: 0.8918
# Epoch 46/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.2693 - accuracy: 0.8951
# Epoch 47/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2705 - accuracy: 0.8984
# Epoch 48/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2744 - accuracy: 0.8885
# Epoch 49/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.2681 - accuracy: 0.9016
# Epoch 50/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2607 - accuracy: 0.9115
# 8/8 [==============================] - 0s 4ms/step - loss: 0.9668 - accuracy: 0.6447
# [CV 2/5; 2/9] END .....batch_size=10, epochs=50;, score=0.645 total time=   3.5s
# [CV 3/5; 2/9] START batch_size=10, epochs=50....................................
# Epoch 1/50
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5789 - accuracy: 0.6787
# Epoch 2/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4807 - accuracy: 0.6787
# Epoch 3/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4618 - accuracy: 0.7672
# Epoch 4/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4483 - accuracy: 0.7803
# Epoch 5/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4425 - accuracy: 0.7967
# Epoch 6/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4352 - accuracy: 0.8000
# Epoch 7/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4251 - accuracy: 0.7967
# Epoch 8/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4214 - accuracy: 0.8000
# Epoch 9/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4167 - accuracy: 0.8164
# Epoch 10/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4091 - accuracy: 0.8197
# Epoch 11/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4083 - accuracy: 0.7967
# Epoch 12/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4031 - accuracy: 0.8066
# Epoch 13/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3973 - accuracy: 0.8098
# Epoch 14/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3939 - accuracy: 0.8164
# Epoch 15/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3894 - accuracy: 0.8098
# Epoch 16/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3885 - accuracy: 0.8164
# Epoch 17/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3884 - accuracy: 0.8131
# Epoch 18/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3898 - accuracy: 0.8164
# Epoch 19/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3975 - accuracy: 0.8131
# Epoch 20/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3745 - accuracy: 0.8426
# Epoch 21/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3776 - accuracy: 0.8295
# Epoch 22/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3827 - accuracy: 0.8262
# Epoch 23/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3769 - accuracy: 0.8295
# Epoch 24/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3717 - accuracy: 0.8295
# Epoch 25/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3729 - accuracy: 0.8361
# Epoch 26/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3700 - accuracy: 0.8590
# Epoch 27/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3678 - accuracy: 0.8361
# Epoch 28/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3681 - accuracy: 0.8262
# Epoch 29/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3666 - accuracy: 0.8393
# Epoch 30/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3717 - accuracy: 0.8393
# Epoch 31/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3606 - accuracy: 0.8393
# Epoch 32/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3608 - accuracy: 0.8459
# Epoch 33/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3612 - accuracy: 0.8426
# Epoch 34/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3721 - accuracy: 0.8361
# Epoch 35/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3631 - accuracy: 0.8459
# Epoch 36/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3572 - accuracy: 0.8459
# Epoch 37/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3571 - accuracy: 0.8426
# Epoch 38/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3544 - accuracy: 0.8393
# Epoch 39/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3549 - accuracy: 0.8426
# Epoch 40/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3531 - accuracy: 0.8492
# Epoch 41/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3509 - accuracy: 0.8492
# Epoch 42/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3490 - accuracy: 0.8492
# Epoch 43/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3479 - accuracy: 0.8459
# Epoch 44/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3485 - accuracy: 0.8492
# Epoch 45/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3485 - accuracy: 0.8492
# Epoch 46/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3455 - accuracy: 0.8525
# Epoch 47/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3424 - accuracy: 0.8492
# Epoch 48/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3406 - accuracy: 0.8525
# Epoch 49/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3462 - accuracy: 0.8459
# Epoch 50/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3342 - accuracy: 0.8492
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4563 - accuracy: 0.7895
# [CV 3/5; 2/9] END .....batch_size=10, epochs=50;, score=0.789 total time=   3.5s
# [CV 4/5; 2/9] START batch_size=10, epochs=50....................................
# Epoch 1/50
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# 31/31 [==============================] - 1s 1ms/step - loss: 0.6084 - accuracy: 0.6656
# Epoch 2/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5046 - accuracy: 0.6656
# Epoch 3/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4817 - accuracy: 0.6820
# Epoch 4/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4727 - accuracy: 0.7607
# Epoch 5/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4672 - accuracy: 0.7803
# Epoch 6/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4615 - accuracy: 0.7803
# Epoch 7/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4578 - accuracy: 0.7770
# Epoch 8/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4458 - accuracy: 0.7902
# Epoch 9/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4427 - accuracy: 0.7869
# Epoch 10/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4429 - accuracy: 0.7836
# Epoch 11/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4342 - accuracy: 0.8131
# Epoch 12/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4198 - accuracy: 0.8033
# Epoch 13/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4181 - accuracy: 0.8033
# Epoch 14/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4151 - accuracy: 0.8033
# Epoch 15/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4020 - accuracy: 0.8131
# Epoch 16/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4106 - accuracy: 0.8230
# Epoch 17/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4092 - accuracy: 0.8098
# Epoch 18/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4055 - accuracy: 0.8164
# Epoch 19/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3975 - accuracy: 0.8164
# Epoch 20/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3979 - accuracy: 0.8131
# Epoch 21/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3914 - accuracy: 0.8230
# Epoch 22/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3909 - accuracy: 0.8262
# Epoch 23/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3875 - accuracy: 0.8295
# Epoch 24/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3948 - accuracy: 0.8197
# Epoch 25/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3877 - accuracy: 0.8230
# Epoch 26/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3841 - accuracy: 0.8230
# Epoch 27/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3829 - accuracy: 0.8328
# Epoch 28/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3848 - accuracy: 0.8197
# Epoch 29/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3848 - accuracy: 0.8295
# Epoch 30/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3782 - accuracy: 0.8262
# Epoch 31/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3866 - accuracy: 0.8328
# Epoch 32/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3783 - accuracy: 0.8230
# Epoch 33/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3698 - accuracy: 0.8492
# Epoch 34/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3859 - accuracy: 0.8262
# Epoch 35/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3853 - accuracy: 0.8361
# Epoch 36/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3707 - accuracy: 0.8459
# Epoch 37/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3733 - accuracy: 0.8328
# Epoch 38/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3690 - accuracy: 0.8426
# Epoch 39/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3644 - accuracy: 0.8492
# Epoch 40/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3601 - accuracy: 0.8393
# Epoch 41/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3586 - accuracy: 0.8426
# Epoch 42/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3663 - accuracy: 0.8361
# Epoch 43/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3661 - accuracy: 0.8426
# Epoch 44/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3599 - accuracy: 0.8393
# Epoch 45/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3697 - accuracy: 0.8230
# Epoch 46/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3695 - accuracy: 0.8426
# Epoch 47/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3766 - accuracy: 0.8393
# Epoch 48/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3796 - accuracy: 0.8295
# Epoch 49/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3683 - accuracy: 0.8230
# Epoch 50/50
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3625 - accuracy: 0.8328
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4342 - accuracy: 0.8289
# [CV 4/5; 2/9] END .....batch_size=10, epochs=50;, score=0.829 total time=   5.8s
# [CV 5/5; 2/9] START batch_size=10, epochs=50....................................
# Epoch 1/50
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# 31/31 [==============================] - 1s 3ms/step - loss: 0.5372 - accuracy: 0.7049
# Epoch 2/50
# 31/31 [==============================] - 0s 3ms/step - loss: 0.4477 - accuracy: 0.7639
# Epoch 3/50
# 31/31 [==============================] - 0s 3ms/step - loss: 0.4240 - accuracy: 0.7803
# Epoch 4/50
# 31/31 [==============================] - 0s 4ms/step - loss: 0.4233 - accuracy: 0.7869
# Epoch 5/50
# 31/31 [==============================] - 0s 5ms/step - loss: 0.4074 - accuracy: 0.7967
# Epoch 6/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4094 - accuracy: 0.8033
# Epoch 7/50
# 31/31 [==============================] - 0s 3ms/step - loss: 0.4010 - accuracy: 0.8197
# Epoch 8/50
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3916 - accuracy: 0.8098
# Epoch 9/50
# 31/31 [==============================] - 0s 4ms/step - loss: 0.3953 - accuracy: 0.8262
# Epoch 10/50
# 31/31 [==============================] - 0s 4ms/step - loss: 0.3888 - accuracy: 0.8197
# Epoch 11/50
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3812 - accuracy: 0.8230
# Epoch 12/50
# 31/31 [==============================] - 0s 4ms/step - loss: 0.3755 - accuracy: 0.8164
# Epoch 13/50
# 31/31 [==============================] - 0s 4ms/step - loss: 0.3816 - accuracy: 0.8295
# Epoch 14/50
# 31/31 [==============================] - 0s 4ms/step - loss: 0.3662 - accuracy: 0.8328
# Epoch 15/50
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3683 - accuracy: 0.8295
# Epoch 16/50
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3719 - accuracy: 0.8262
# Epoch 17/50
# 31/31 [==============================] - 0s 4ms/step - loss: 0.3629 - accuracy: 0.8393
# Epoch 18/50
# 31/31 [==============================] - 0s 4ms/step - loss: 0.3639 - accuracy: 0.8262
# Epoch 19/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3703 - accuracy: 0.8262
# Epoch 20/50
# 31/31 [==============================] - 0s 4ms/step - loss: 0.3540 - accuracy: 0.8393
# Epoch 21/50
# 31/31 [==============================] - 0s 6ms/step - loss: 0.3509 - accuracy: 0.8426
# Epoch 22/50
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3498 - accuracy: 0.8295
# Epoch 23/50
# 31/31 [==============================] - 0s 4ms/step - loss: 0.3537 - accuracy: 0.8295
# Epoch 24/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3474 - accuracy: 0.8525
# Epoch 25/50
# 31/31 [==============================] - 0s 4ms/step - loss: 0.3545 - accuracy: 0.8262
# Epoch 26/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3631 - accuracy: 0.8230
# Epoch 27/50
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3448 - accuracy: 0.8492
# Epoch 28/50
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3363 - accuracy: 0.8557
# Epoch 29/50
# 31/31 [==============================] - 0s 4ms/step - loss: 0.3413 - accuracy: 0.8459
# Epoch 30/50
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3280 - accuracy: 0.8590
# Epoch 31/50
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3308 - accuracy: 0.8492
# Epoch 32/50
# 31/31 [==============================] - 0s 5ms/step - loss: 0.3325 - accuracy: 0.8623
# Epoch 33/50
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3243 - accuracy: 0.8459
# Epoch 34/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3361 - accuracy: 0.8492
# Epoch 35/50
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3269 - accuracy: 0.8525
# Epoch 36/50
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3245 - accuracy: 0.8492
# Epoch 37/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3300 - accuracy: 0.8623
# Epoch 38/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3261 - accuracy: 0.8656
# Epoch 39/50
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3239 - accuracy: 0.8525
# Epoch 40/50
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3210 - accuracy: 0.8754
# Epoch 41/50
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3113 - accuracy: 0.8623
# Epoch 42/50
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3113 - accuracy: 0.8754
# Epoch 43/50
# 31/31 [==============================] - 0s 5ms/step - loss: 0.3136 - accuracy: 0.8689
# Epoch 44/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3098 - accuracy: 0.8623
# Epoch 45/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3235 - accuracy: 0.8623
# Epoch 46/50
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3067 - accuracy: 0.8656
# Epoch 47/50
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3056 - accuracy: 0.8754
# Epoch 48/50
# 31/31 [==============================] - 0s 4ms/step - loss: 0.3105 - accuracy: 0.8623
# Epoch 49/50
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3096 - accuracy: 0.8656
# Epoch 50/50
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3050 - accuracy: 0.8689
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5771 - accuracy: 0.7632
# [CV 5/5; 2/9] END .....batch_size=10, epochs=50;, score=0.763 total time=   7.0s
# [CV 1/5; 3/9] START batch_size=10, epochs=100...................................
# Epoch 1/100
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# 31/31 [==============================] - 1s 3ms/step - loss: 0.5799 - accuracy: 0.6711
# Epoch 2/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4900 - accuracy: 0.6711
# Epoch 3/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.4590 - accuracy: 0.7599
# Epoch 4/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.4464 - accuracy: 0.7862
# Epoch 5/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4315 - accuracy: 0.7993
# Epoch 6/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.4189 - accuracy: 0.8191
# Epoch 7/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.4057 - accuracy: 0.8355
# Epoch 8/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.4093 - accuracy: 0.8026
# Epoch 9/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3814 - accuracy: 0.8454
# Epoch 10/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3803 - accuracy: 0.8487
# Epoch 11/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3786 - accuracy: 0.8289
# Epoch 12/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3632 - accuracy: 0.8586
# Epoch 13/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3560 - accuracy: 0.8454
# Epoch 14/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3558 - accuracy: 0.8553
# Epoch 15/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3505 - accuracy: 0.8586
# Epoch 16/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3398 - accuracy: 0.8553
# Epoch 17/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3396 - accuracy: 0.8618
# Epoch 18/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3383 - accuracy: 0.8586
# Epoch 19/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3426 - accuracy: 0.8520
# Epoch 20/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3377 - accuracy: 0.8651
# Epoch 21/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3390 - accuracy: 0.8454
# Epoch 22/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3305 - accuracy: 0.8651
# Epoch 23/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3295 - accuracy: 0.8684
# Epoch 24/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3386 - accuracy: 0.8586
# Epoch 25/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3296 - accuracy: 0.8618
# Epoch 26/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3190 - accuracy: 0.8651
# Epoch 27/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3274 - accuracy: 0.8717
# Epoch 28/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3372 - accuracy: 0.8618
# Epoch 29/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3228 - accuracy: 0.8618
# Epoch 30/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3079 - accuracy: 0.8783
# Epoch 31/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3093 - accuracy: 0.8849
# Epoch 32/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3162 - accuracy: 0.8816
# Epoch 33/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3082 - accuracy: 0.8849
# Epoch 34/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3030 - accuracy: 0.8816
# Epoch 35/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3042 - accuracy: 0.8717
# Epoch 36/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3145 - accuracy: 0.8717
# Epoch 37/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3046 - accuracy: 0.8816
# Epoch 38/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2999 - accuracy: 0.8684
# Epoch 39/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3010 - accuracy: 0.8750
# Epoch 40/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.2953 - accuracy: 0.8783
# Epoch 41/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3010 - accuracy: 0.8717
# Epoch 42/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2933 - accuracy: 0.8750
# Epoch 43/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.2943 - accuracy: 0.8750
# Epoch 44/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2885 - accuracy: 0.8783
# Epoch 45/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2961 - accuracy: 0.8816
# Epoch 46/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2881 - accuracy: 0.8783
# Epoch 47/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2795 - accuracy: 0.8816
# Epoch 48/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.2921 - accuracy: 0.8717
# Epoch 49/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.2957 - accuracy: 0.8816
# Epoch 50/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.2840 - accuracy: 0.8750
# Epoch 51/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.2863 - accuracy: 0.8750
# Epoch 52/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2911 - accuracy: 0.8783
# Epoch 53/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2807 - accuracy: 0.8882
# Epoch 54/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2825 - accuracy: 0.8816
# Epoch 55/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2765 - accuracy: 0.8816
# Epoch 56/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2784 - accuracy: 0.8849
# Epoch 57/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.2937 - accuracy: 0.8717
# Epoch 58/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.2819 - accuracy: 0.8816
# Epoch 59/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.2806 - accuracy: 0.8816
# Epoch 60/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.2739 - accuracy: 0.8882
# Epoch 61/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2703 - accuracy: 0.8783
# Epoch 62/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2905 - accuracy: 0.8750
# Epoch 63/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2731 - accuracy: 0.8882
# Epoch 64/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2769 - accuracy: 0.8816
# Epoch 65/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.2739 - accuracy: 0.8816
# Epoch 66/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2753 - accuracy: 0.8816
# Epoch 67/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2706 - accuracy: 0.8914
# Epoch 68/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.2743 - accuracy: 0.8783
# Epoch 69/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.2702 - accuracy: 0.8947
# Epoch 70/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2770 - accuracy: 0.8750
# Epoch 71/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.2913 - accuracy: 0.8816
# Epoch 72/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.2837 - accuracy: 0.8914
# Epoch 73/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.2754 - accuracy: 0.8914
# Epoch 74/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2677 - accuracy: 0.8947
# Epoch 75/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2670 - accuracy: 0.8914
# Epoch 76/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.2667 - accuracy: 0.8914
# Epoch 77/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.2564 - accuracy: 0.8947
# Epoch 78/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.2568 - accuracy: 0.8947
# Epoch 79/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.2532 - accuracy: 0.9079
# Epoch 80/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.2465 - accuracy: 0.9013
# Epoch 81/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.2416 - accuracy: 0.9013
# Epoch 82/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.2417 - accuracy: 0.9079
# Epoch 83/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.2461 - accuracy: 0.9046
# Epoch 84/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2442 - accuracy: 0.8980
# Epoch 85/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.2547 - accuracy: 0.8980
# Epoch 86/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2658 - accuracy: 0.8947
# Epoch 87/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2357 - accuracy: 0.9112
# Epoch 88/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.2461 - accuracy: 0.8980
# Epoch 89/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2516 - accuracy: 0.8947
# Epoch 90/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.2353 - accuracy: 0.9145
# Epoch 91/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.2233 - accuracy: 0.9112
# Epoch 92/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2320 - accuracy: 0.9145
# Epoch 93/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.2322 - accuracy: 0.9112
# Epoch 94/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.2407 - accuracy: 0.9046
# Epoch 95/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.2265 - accuracy: 0.9112
# Epoch 96/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.2182 - accuracy: 0.9211
# Epoch 97/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2178 - accuracy: 0.9178
# Epoch 98/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2266 - accuracy: 0.9211
# Epoch 99/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2500 - accuracy: 0.9112
# Epoch 100/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.2542 - accuracy: 0.8947
# 8/8 [==============================] - 0s 2ms/step - loss: 1.2179 - accuracy: 0.7532
# [CV 1/5; 3/9] END ....batch_size=10, epochs=100;, score=0.753 total time=   7.6s
# [CV 2/5; 3/9] START batch_size=10, epochs=100...................................
# Epoch 1/100
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5999 - accuracy: 0.7213
# Epoch 2/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4274 - accuracy: 0.8033
# Epoch 3/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3875 - accuracy: 0.8066
# Epoch 4/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3773 - accuracy: 0.8164
# Epoch 5/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3654 - accuracy: 0.8295
# Epoch 6/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3657 - accuracy: 0.8393
# Epoch 7/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3615 - accuracy: 0.8361
# Epoch 8/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3571 - accuracy: 0.8492
# Epoch 9/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3580 - accuracy: 0.8393
# Epoch 10/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3544 - accuracy: 0.8459
# Epoch 11/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3514 - accuracy: 0.8459
# Epoch 12/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3453 - accuracy: 0.8590
# Epoch 13/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3426 - accuracy: 0.8426
# Epoch 14/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3459 - accuracy: 0.8492
# Epoch 15/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3402 - accuracy: 0.8590
# Epoch 16/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3355 - accuracy: 0.8557
# Epoch 17/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3300 - accuracy: 0.8525
# Epoch 18/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3313 - accuracy: 0.8590
# Epoch 19/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3329 - accuracy: 0.8525
# Epoch 20/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3299 - accuracy: 0.8557
# Epoch 21/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3195 - accuracy: 0.8590
# Epoch 22/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3177 - accuracy: 0.8656
# Epoch 23/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3234 - accuracy: 0.8525
# Epoch 24/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3064 - accuracy: 0.8656
# Epoch 25/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3162 - accuracy: 0.8557
# Epoch 26/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3050 - accuracy: 0.8754
# Epoch 27/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3016 - accuracy: 0.8721
# Epoch 28/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3004 - accuracy: 0.8820
# Epoch 29/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2992 - accuracy: 0.8820
# Epoch 30/100
# ...
# Epoch 50/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3500 - accuracy: 0.8492
# Epoch 51/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3487 - accuracy: 0.8459
# Epoch 52/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3447 - accuracy: 0.8492
# Epoch 53/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3449 - accuracy: 0.8492
# Epoch 54/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3409 - accuracy: 0.8557
# Epoch 55/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3392 - accuracy: 0.8525
# Epoch 56/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3404 - accuracy: 0.8492
# Epoch 57/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3389 - accuracy: 0.8525
# Epoch 58/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3382 - accuracy: 0.8590
# Epoch 59/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3367 - accuracy: 0.8525
# Epoch 60/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3421 - accuracy: 0.8426
# Epoch 61/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3398 - accuracy: 0.8426
# Epoch 62/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3381 - accuracy: 0.8525
# Epoch 63/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3377 - accuracy: 0.8426
# Epoch 64/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3342 - accuracy: 0.8525
# Epoch 65/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3320 - accuracy: 0.8557
# Epoch 66/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3299 - accuracy: 0.8492
# Epoch 67/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3301 - accuracy: 0.8557
# Epoch 68/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3269 - accuracy: 0.8557
# Epoch 69/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3272 - accuracy: 0.8557
# Epoch 70/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3266 - accuracy: 0.8590
# Epoch 71/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3251 - accuracy: 0.8590
# Epoch 72/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3256 - accuracy: 0.8525
# Epoch 73/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3247 - accuracy: 0.8623
# Epoch 74/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3222 - accuracy: 0.8623
# Epoch 75/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3253 - accuracy: 0.8557
# Epoch 76/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3248 - accuracy: 0.8590
# Epoch 77/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3195 - accuracy: 0.8689
# Epoch 78/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3202 - accuracy: 0.8689
# Epoch 79/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3206 - accuracy: 0.8557
# Epoch 80/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3273 - accuracy: 0.8590
# Epoch 81/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3176 - accuracy: 0.8590
# Epoch 82/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3107 - accuracy: 0.8656
# Epoch 83/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3137 - accuracy: 0.8656
# Epoch 84/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3093 - accuracy: 0.8820
# Epoch 85/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3082 - accuracy: 0.8689
# Epoch 86/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3103 - accuracy: 0.8590
# Epoch 87/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3055 - accuracy: 0.8754
# Epoch 88/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3072 - accuracy: 0.8787
# Epoch 89/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3078 - accuracy: 0.8721
# Epoch 90/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3052 - accuracy: 0.8689
# Epoch 91/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3029 - accuracy: 0.8787
# Epoch 92/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3029 - accuracy: 0.8721
# Epoch 93/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2999 - accuracy: 0.8689
# Epoch 94/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2986 - accuracy: 0.8721
# Epoch 95/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3039 - accuracy: 0.8721
# Epoch 96/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3001 - accuracy: 0.8754
# Epoch 97/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3004 - accuracy: 0.8656
# Epoch 98/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2970 - accuracy: 0.8787
# Epoch 99/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2946 - accuracy: 0.8787
# Epoch 100/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3013 - accuracy: 0.8557
# 2/2 [==============================] - 0s 6ms/step - loss: 0.4911 - accuracy: 0.7632
# [CV 5/5; 9/9] END ....batch_size=40, epochs=100;, score=0.763 total time=   3.7s
# Epoch 1/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6735 - accuracy: 0.7244
# Epoch 2/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6286 - accuracy: 0.7559
# Epoch 3/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5901 - accuracy: 0.7848
# Epoch 4/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5592 - accuracy: 0.7822
# Epoch 5/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5354 - accuracy: 0.7874
# Epoch 6/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5251 - accuracy: 0.8031
# Epoch 7/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5162 - accuracy: 0.7822
# Epoch 8/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5013 - accuracy: 0.8005
# Epoch 9/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5043 - accuracy: 0.8005
# Epoch 10/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4824 - accuracy: 0.8163
# Epoch 11/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4780 - accuracy: 0.8031
# Epoch 12/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4700 - accuracy: 0.8110
# Epoch 13/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4789 - accuracy: 0.7953
# Epoch 14/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4576 - accuracy: 0.8084
# Epoch 15/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4571 - accuracy: 0.7953
# Epoch 16/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4449 - accuracy: 0.8163
# Epoch 17/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4377 - accuracy: 0.8084
# Epoch 18/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4328 - accuracy: 0.8136
# Epoch 19/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4353 - accuracy: 0.8005
# Epoch 20/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4333 - accuracy: 0.7953
# Epoch 21/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4257 - accuracy: 0.8084
# Epoch 22/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4166 - accuracy: 0.8163
# Epoch 23/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4143 - accuracy: 0.8163
# Epoch 24/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4106 - accuracy: 0.8136
# Epoch 25/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4041 - accuracy: 0.8268
# Epoch 26/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4295 - accuracy: 0.8084
# Epoch 27/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4275 - accuracy: 0.8189
# Epoch 28/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4019 - accuracy: 0.8163
# Epoch 29/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4021 - accuracy: 0.8189
# Epoch 30/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3910 - accuracy: 0.8268
# Epoch 31/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4124 - accuracy: 0.8163
# Epoch 32/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4200 - accuracy: 0.8215
# Epoch 33/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3999 - accuracy: 0.8268
# Epoch 34/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3969 - accuracy: 0.8189
# Epoch 35/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3865 - accuracy: 0.8294
# Epoch 36/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3903 - accuracy: 0.8346
# Epoch 37/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4064 - accuracy: 0.8215
# Epoch 38/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3865 - accuracy: 0.8373
# Epoch 39/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3854 - accuracy: 0.8268
# Epoch 40/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3760 - accuracy: 0.8373
# Epoch 41/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3783 - accuracy: 0.8373
# Epoch 42/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3667 - accuracy: 0.8425
# Epoch 43/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3750 - accuracy: 0.8504
# Epoch 44/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3700 - accuracy: 0.8451
# Epoch 45/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3629 - accuracy: 0.8504
# Epoch 46/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3603 - accuracy: 0.8478
# Epoch 47/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4084 - accuracy: 0.8215
# Epoch 48/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3884 - accuracy: 0.8478
# Epoch 49/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3743 - accuracy: 0.8451
# Epoch 50/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3583 - accuracy: 0.8478
# Epoch 51/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3788 - accuracy: 0.8320
# Epoch 52/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3689 - accuracy: 0.8451
# Epoch 53/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3546 - accuracy: 0.8556
# Epoch 54/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3472 - accuracy: 0.8661
# Epoch 55/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3454 - accuracy: 0.8583
# Epoch 56/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3425 - accuracy: 0.8609
# Epoch 57/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3405 - accuracy: 0.8635
# Epoch 58/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3520 - accuracy: 0.8504
# Epoch 59/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3478 - accuracy: 0.8556
# Epoch 60/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3407 - accuracy: 0.8609
# Epoch 61/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3372 - accuracy: 0.8661
# Epoch 62/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3344 - accuracy: 0.8661
# Epoch 63/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3364 - accuracy: 0.8793
# Epoch 64/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3314 - accuracy: 0.8740
# Epoch 65/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4113 - accuracy: 0.8163
# Epoch 66/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3785 - accuracy: 0.8136
# Epoch 67/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3604 - accuracy: 0.8451
# Epoch 68/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3481 - accuracy: 0.8556
# Epoch 69/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3409 - accuracy: 0.8504
# Epoch 70/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3407 - accuracy: 0.8556
# Epoch 71/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3366 - accuracy: 0.8504
# Epoch 72/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3293 - accuracy: 0.8688
# Epoch 73/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3268 - accuracy: 0.8661
# Epoch 74/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3271 - accuracy: 0.8661
# Epoch 75/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3319 - accuracy: 0.8556
# Epoch 76/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3223 - accuracy: 0.8556
# Epoch 77/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3191 - accuracy: 0.8556
# Epoch 78/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3214 - accuracy: 0.8714
# Epoch 79/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3195 - accuracy: 0.8530
# Epoch 80/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4326 - accuracy: 0.8320
# Epoch 81/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3502 - accuracy: 0.8478
# Epoch 82/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3281 - accuracy: 0.8635
# Epoch 83/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3256 - accuracy: 0.8556
# Epoch 84/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3176 - accuracy: 0.8635
# Epoch 85/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3139 - accuracy: 0.8609
# Epoch 86/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3137 - accuracy: 0.8714
# Epoch 87/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3116 - accuracy: 0.8714
# Epoch 88/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3129 - accuracy: 0.8714
# Epoch 89/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3056 - accuracy: 0.8688
# Epoch 90/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3136 - accuracy: 0.8609
# Epoch 91/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3155 - accuracy: 0.8740
# Epoch 92/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3045 - accuracy: 0.8793
# Epoch 93/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3063 - accuracy: 0.8766
# Epoch 94/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3052 - accuracy: 0.8661
# Epoch 95/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2994 - accuracy: 0.8714
# Epoch 96/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3182 - accuracy: 0.8766
# Epoch 97/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3011 - accuracy: 0.8714
# Epoch 98/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3177 - accuracy: 0.8688
# Epoch 99/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3189 - accuracy: 0.8530
# Epoch 100/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3002 - accuracy: 0.8740
# Best: 0.7718045115470886, using {'batch_size': 20, 'epochs': 100}
# 0.7664388179779053 (0.060656755012734674) with: {'batch_size': 10, 'epochs': 10}
# 0.7533151149749756 (0.06178065850048965) with: {'batch_size': 10, 'epochs': 50}
# 0.7401230216026307 (0.04452095802687758) with: {'batch_size': 10, 'epochs': 100}
# 0.7453178405761719 (0.0807467571059437) with: {'batch_size': 20, 'epochs': 10}
# 0.753212571144104 (0.039750682328794036) with: {'batch_size': 20, 'epochs': 50}
# 0.7718045115470886 (0.0759603074861406) with: {'batch_size': 20, 'epochs': 100}
# 0.7690020442008972 (0.06644514025088182) with: {'batch_size': 40, 'epochs': 10}
# 0.7585782647132874 (0.0640352461919735) with: {'batch_size': 40, 'epochs': 50}
# 0.7586124539375305 (0.0644176297996685) with: {'batch_size': 40, 'epochs': 100}

# %% [markdown]
# **Do a grid search to find the optimal number of neurons in each hidden layer**

# %%
# import necessary packages

# Define a random seed
seed = 6
np.random.seed(seed)

# Start defining the model
def create_model(neuron1, neuron2):
    # create model
    model = Sequential()
    model.add(Dense(neuron1, input_dim = 8, kernel_initializer= 'uniform', activation= 'linear'))
    model.add(Dense(neuron2, input_dim = neuron1, kernel_initializer= 'uniform', activation= 'linear'))
    model.add(Dense(1, activation='sigmoid'))
    
    # compile the model
    adam = Adam(lr = 0.001)
    model.compile(loss = 'binary_crossentropy', optimizer = adam, metrics = ['accuracy'])
    return model

# create the model
model = KerasClassifier(build_fn = create_model, epochs = 100, batch_size = 20, verbose = 0)

# define the grid search parameters
neuron1 = [4, 8, 16]
neuron2 = [2, 4, 8]

# make a dictionary of the grid search parameters
param_grid = dict(neuron1 = neuron1, neuron2 = neuron2)

# build and fit the GridSearchCV
grid = GridSearchCV(estimator = model, param_grid = param_grid, cv = KFold(random_state=seed), refit = True, verbose = 10)
grid_results = grid.fit(X_standardized, Y)

# summarize the results
print("Best: {0}, using {1}".format(grid_results.best_score_, grid_results.best_params_))
means = grid_results.cv_results_['mean_test_score']
stds = grid_results.cv_results_['std_test_score']
params = grid_results.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print('{0} ({1}) with: {2}'.format(mean, stdev, param))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:21: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-af9d4a3b01e8> in <module>()
#      29
#      30 # build and fit the GridSearchCV
# ---> 31 grid = GridSearchCV(estimator = model, param_grid = param_grid, cv = KFold(random_state=seed), refit = True, verbose = 10)
#      32 grid_results = grid.fit(X_standardized, Y)
#      33
#
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_split.py in __init__(self, n_splits, shuffle, random_state)
#     433
#     434     def __init__(self, n_splits=5, *, shuffle=False, random_state=None):
# --> 435         super().__init__(n_splits=n_splits, shuffle=shuffle, random_state=random_state)
#     436
#     437     def _iter_test_indices(self, X, y=None, groups=None):
#
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_split.py in __init__(self, n_splits, shuffle, random_state)
#     295         if not shuffle and random_state is not None:  # None is the default
#     296             raise ValueError(
# --> 297                 "Setting a random_state has no effect since shuffle is "
#     298                 "False. You should leave "
#     299                 "random_state to its default (None), or set shuffle=True.",
#
# ValueError: Setting a random_state has no effect since shuffle is False. You should leave random_state to its default (None), or set shuffle=True.

# %% [markdown]
# **Generate predictions with optimal hyperparameters**

# %%
y_pred = grid.predict(X_standardized)

# %%
print(y_pred.shape)

# %%
print(y_pred[:5])

# %% [markdown]
# <h2>Generate a classification report</h2>

# %%
from sklearn.metrics import classification_report, accuracy_score

print(accuracy_score(Y, y_pred))
print(classification_report(Y, y_pred))

# %% [markdown]
#  # <font color='green'>Please do the following: Take the example and find a dataset that can apply the same process
#  </font>
